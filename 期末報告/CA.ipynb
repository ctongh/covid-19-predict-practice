# %%
from pylab import *
from scipy import interpolate
from random import random
from math import log
from enum import Enum

# %%
pop = [3955, 2870, 2129, 1954, 1274, 1168, 1280, 1051, 677, 1038]
conf_d0 = [3, 2, 2, 2, 1, 1, 1, 1, 1, 1]
recover = []

# %%
# Exponential Distribution

# 感染事件
def InfectiousEvent(rate, dt):
    try:
        return -log(random()) / rate*2000 < dt
    except ZeroDivisionError:
        return 0

# 康復事件
def RecoveredEvent(rate, dt):
    try:
        return -log(random()) / rate*1.25 < dt
    except ZeroDivisionError:
        return 0


# Parameters
Beta = 1     ## 感染力
Gamma = 0.5  ## 康復力
#######  R0 = beta / gamma = 1 / 0.5 = 2 ###### 
#N = 1000     ## 該地總人口
day = 20     ## 模擬天數
#I0 = 1      ## 第一天確診人口


class State(Enum):
    SUS = 1
    INF = 2
    RECV = 3


class Person:
    def __init__(self, id, state):
        self.id = id
        self.state = state

    def step(self, people, dt=1):
        if self.state == State.SUS:
            new_beta = 0

            # suppose that touch all people,
            # and add all's beta as new beta
            for person in people:
                if person.state == State.INF:
                    new_beta += Beta

            if InfectiousEvent(new_beta, dt):
                self.state = State.INF

        elif self.state == State.INF:
            if RecoveredEvent(Gamma, dt):
                self.state = State.RECV


def sir_count(people):
    s = 0
    i = 0
    r = 0
    for p in people:
        if p.state == State.SUS:
            s += 1
        elif p.state == State.INF:
            i += 1
        else:
            r += 1
    return s, i, r


for sta in range(0, 10):
    N = pop[sta]
    I0 = conf_d0[sta]
    
    if __name__ == '__main__':
        
        LS = []
        LI = []
        LR = []

        people = []
        for i in range(0, N - I0):
            people.append(Person(i, State.SUS))
        for i in range(0, I0):
            people.append(Person(i, State.INF))

        for day in range(0, day + 1):
            s, i, r = sir_count(people)
            LS.append(s)
            LI.append(i)
            LR.append(r)
            print("第{}天，易感受：{}人， 已確診：{}人， 已康復：{}人".format(day, s, i, r))
        
            for person in people:
                person.step(people)


    # Draw the figure
        t = arange(0, day + 1, 1)
        ls = interpolate.InterpolatedUnivariateSpline(t, LS)
        li = interpolate.InterpolatedUnivariateSpline(t, LI)
        lr = interpolate.InterpolatedUnivariateSpline(t, LR)
        tnew = arange(0.001, day, 1/20)
        lsnew = ls(tnew)
        linew = li(tnew)
        lrnew = lr(tnew)
        line1, = plot(tnew, lsnew, label='S')
        line2, = plot(tnew, linew, label='I')
        line3, = plot(tnew, lrnew, label='R')

        legend(handles=[line1, line2, line3],
               shadow=True, loc=(0.85, 0.4))  # handle

        line11, = plot(t, LS, '.')
        line22, = plot(t, LI, '.')
        line33, = plot(t, LR, '.')

        text(16.5, 240, 'Beta=%g' % (Beta))
        text(16.5, 190, 'Gamma=%g' % (Gamma))
        text(16.5, 150, 'Infected:%d' % (I0))
        v = [0, day, 0, N]
        axis(v)
        xlabel('time (days)')
        ylabel('Population(people)')
        title('SIR Model')
        grid(True)
        show()
# Out:
# 第0天，易感受：3952人， 已確診：3人， 已康復：0人
# 第1天，易感受：3922人， 已確診：32人， 已康復：1人
# 第2天，易感受：3740人， 已確診：202人， 已康復：13人
# 第3天，易感受：2894人， 已確診：992人， 已康復：69人
# 第4天，易感受：1271人， 已確診：2288人， 已康復：396人
# 第5天，易感受：324人， 已確診：2497人， 已康復：1134人
# 第6天，易感受：105人， 已確診：1906人， 已康復：1944人
# 第7天，易感受：44人， 已確診：1347人， 已康復：2564人
# 第8天，易感受：23人， 已確診：945人， 已康復：2987人
# 第9天，易感受：15人， 已確診：637人， 已康復：3303人
# 第10天，易感受：9人， 已確診：429人， 已康復：3517人
# 第11天，易感受：9人， 已確診：281人， 已康復：3665人
# 第12天，易感受：9人， 已確診：192人， 已康復：3754人
# 第13天，易感受：8人， 已確診：123人， 已康復：3824人
# 第14天，易感受：8人， 已確診：83人， 已康復：3864人
# 第15天，易感受：5人， 已確診：64人， 已康復：3886人
# 第16天，易感受：5人， 已確診：47人， 已康復：3903人
# 第17天，易感受：5人， 已確診：25人， 已康復：3925人
# 第18天，易感受：5人， 已確診：13人， 已康復：3937人
# 第19天，易感受：5人， 已確診：6人， 已康復：3944人
# 第20天，易感受：5人， 已確診：4人， 已康復：3946人
# 第0天，易感受：2868人， 已確診：2人， 已康復：0人
# 第1天，易感受：2861人， 已確診：9人， 已康復：0人
# 第2天，易感受：2840人， 已確診：29人， 已康復：1人
# 第3天，易感受：2746人， 已確診：117人， 已康復：7人
# 第4天，易感受：2405人， 已確診：418人， 已康復：47人
# 第5天，易感受：1800人， 已確診：886人， 已康復：184人
# 第6天，易感受：1073人， 已確診：1333人， 已康復：464人
# 第7天，易感受：540人， 已確診：1398人， 已康復：932人
# 第8天，易感受：279人， 已確診：1200人， 已康復：1391人
# 第9天，易感受：165人， 已確診：904人， 已康復：1801人
# 第10天，易感受：114人， 已確診：661人， 已康復：2095人
# 第11天，易感受：87人， 已確診：479人， 已康復：2304人
# 第12天，易感受：71人， 已確診：352人， 已康復：2447人
# 第13天，易感受：59人， 已確診：251人， 已康復：2560人
# 第14天，易感受：58人， 已確診：170人， 已康復：2642人
# 第15天，易感受：54人， 已確診：129人， 已康復：2687人
# 第16天，易感受：51人， 已確診：91人， 已康復：2728人
# 第17天，易感受：47人， 已確診：62人， 已康復：2761人
# 第18天，易感受：44人， 已確診：44人， 已康復：2782人
# 第19天，易感受：43人， 已確診：28人， 已康復：2799人
# 第20天，易感受：43人， 已確診：17人， 已康復：2810人
# 第0天，易感受：2127人， 已確診：2人， 已康復：0人
# 第1天，易感受：2124人， 已確診：5人， 已康復：0人
# 第2天，易感受：2105人， 已確診：22人， 已康復：2人
# 第3天，易感受：2068人， 已確診：54人， 已康復：7人
# 第4天，易感受：2004人， 已確診：100人， 已康復：25人
# 第5天，易感受：1880人， 已確診：199人， 已康復：50人
# 第6天，易感受：1644人， 已確診：377人， 已康復：108人
# 第7天，易感受：1299人， 已確診：614人， 已康復：216人
# 第8天，易感受：927人， 已確診：782人， 已康復：420人
# 第9天，易感受：616人， 已確診：803人， 已康復：710人
# 第10天，易感受：420人， 已確診：755人， 已康復：954人
# 第11天，易感受：301人， 已確診：623人， 已康復：1205人
# 第12天，易感受：225人， 已確診：483人， 已康復：1421人
# 第13天，易感受：183人， 已確診：371人， 已康復：1575人
# 第14天，易感受：159人， 已確診：269人， 已康復：1701人
# 第15天，易感受：140人， 已確診：193人， 已康復：1796人
# 第16天，易感受：124人， 已確診：150人， 已康復：1855人
# 第17天，易感受：117人， 已確診：103人， 已康復：1909人
# 第18天，易感受：108人， 已確診：76人， 已康復：1945人
# 第19天，易感受：102人， 已確診：56人， 已康復：1971人
# 第20天，易感受：97人， 已確診：41人， 已康復：1991人
# 第0天，易感受：1952人， 已確診：2人， 已康復：0人
# 第1天，易感受：1949人， 已確診：5人， 已康復：0人
# 第2天，易感受：1943人， 已確診：10人， 已康復：1人
# 第3天，易感受：1928人， 已確診：22人， 已康復：4人
# 第4天，易感受：1916人， 已確診：30人， 已康復：8人
# 第5天，易感受：1889人， 已確診：46人， 已康復：19人
# 第6天，易感受：1835人， 已確診：90人， 已康復：29人
# 第7天，易感受：1697人， 已確診：200人， 已康復：57人
# 第8天，易感受：1492人， 已確診：341人， 已康復：121人
# 第9天，易感受：1179人， 已確診：542人， 已康復：233人
# 第10天，易感受：859人， 已確診：684人， 已康復：411人
# 第11天，易感受：609人， 已確診：690人， 已康復：655人
# 第12天，易感受：443人， 已確診：620人， 已康復：891人
# 第13天，易感受：340人， 已確診：509人， 已康復：1105人
# 第14天，易感受：284人， 已確診：404人， 已康復：1266人
# 第15天，易感受：239人， 已確診：319人， 已康復：1396人
# 第16天，易感受：203人， 已確診：253人， 已康復：1498人
# 第17天，易感受：188人， 已確診：177人， 已康復：1589人
# 第18天，易感受：175人， 已確診：132人， 已康復：1647人
# 第19天，易感受：168人， 已確診：91人， 已康復：1695人
# 第20天，易感受：161人， 已確診：73人， 已康復：1720人
# 第0天，易感受：1273人， 已確診：1人， 已康復：0人
# 第1天，易感受：1273人， 已確診：1人， 已康復：0人
# 第2天，易感受：1273人， 已確診：0人， 已康復：1人
# 第3天，易感受：1273人， 已確診：0人， 已康復：1人
# 第4天，易感受：1273人， 已確診：0人， 已康復：1人
# 第5天，易感受：1273人， 已確診：0人， 已康復：1人
# 第6天，易感受：1273人， 已確診：0人， 已康復：1人
# 第7天，易感受：1273人， 已確診：0人， 已康復：1人
# 第8天，易感受：1273人， 已確診：0人， 已康復：1人
# 第9天，易感受：1273人， 已確診：0人， 已康復：1人
# 第10天，易感受：1273人， 已確診：0人， 已康復：1人
# 第11天，易感受：1273人， 已確診：0人， 已康復：1人
# 第12天，易感受：1273人， 已確診：0人， 已康復：1人
# 第13天，易感受：1273人， 已確診：0人， 已康復：1人
# 第14天，易感受：1273人， 已確診：0人， 已康復：1人
# 第15天，易感受：1273人， 已確診：0人， 已康復：1人
# 第16天，易感受：1273人， 已確診：0人， 已康復：1人
# 第17天，易感受：1273人， 已確診：0人， 已康復：1人
# 第18天，易感受：1273人， 已確診：0人， 已康復：1人
# 第19天，易感受：1273人， 已確診：0人， 已康復：1人
# 第20天，易感受：1273人， 已確診：0人， 已康復：1人
# 第0天，易感受：1167人， 已確診：1人， 已康復：0人
# 第1天，易感受：1166人， 已確診：1人， 已康復：1人
# 第2天，易感受：1166人， 已確診：0人， 已康復：2人
# 第3天，易感受：1166人， 已確診：0人， 已康復：2人
# 第4天，易感受：1166人， 已確診：0人， 已康復：2人
# 第5天，易感受：1166人， 已確診：0人， 已康復：2人
# 第6天，易感受：1166人， 已確診：0人， 已康復：2人
# 第7天，易感受：1166人， 已確診：0人， 已康復：2人
# 第8天，易感受：1166人， 已確診：0人， 已康復：2人
# 第9天，易感受：1166人， 已確診：0人， 已康復：2人
# 第10天，易感受：1166人， 已確診：0人， 已康復：2人
# 第11天，易感受：1166人， 已確診：0人， 已康復：2人
# 第12天，易感受：1166人， 已確診：0人， 已康復：2人
# 第13天，易感受：1166人， 已確診：0人， 已康復：2人
# 第14天，易感受：1166人， 已確診：0人， 已康復：2人
# 第15天，易感受：1166人， 已確診：0人， 已康復：2人
# 第16天，易感受：1166人， 已確診：0人， 已康復：2人
# 第17天，易感受：1166人， 已確診：0人， 已康復：2人
# 第18天，易感受：1166人， 已確診：0人， 已康復：2人
# 第19天，易感受：1166人， 已確診：0人， 已康復：2人
# 第20天，易感受：1166人， 已確診：0人， 已康復：2人
# 第0天，易感受：1279人， 已確診：1人， 已康復：0人
# 第1天，易感受：1279人， 已確診：1人， 已康復：0人
# 第2天，易感受：1279人， 已確診：0人， 已康復：1人
# 第3天，易感受：1279人， 已確診：0人， 已康復：1人
# 第4天，易感受：1279人， 已確診：0人， 已康復：1人
# 第5天，易感受：1279人， 已確診：0人， 已康復：1人
# 第6天，易感受：1279人， 已確診：0人， 已康復：1人
# 第7天，易感受：1279人， 已確診：0人， 已康復：1人
# 第8天，易感受：1279人， 已確診：0人， 已康復：1人
# 第9天，易感受：1279人， 已確診：0人， 已康復：1人
# 第10天，易感受：1279人， 已確診：0人， 已康復：1人
# 第11天，易感受：1279人， 已確診：0人， 已康復：1人
# 第12天，易感受：1279人， 已確診：0人， 已康復：1人
# 第13天，易感受：1279人， 已確診：0人， 已康復：1人
# 第14天，易感受：1279人， 已確診：0人， 已康復：1人
# 第15天，易感受：1279人， 已確診：0人， 已康復：1人
# 第16天，易感受：1279人， 已確診：0人， 已康復：1人
# 第17天，易感受：1279人， 已確診：0人， 已康復：1人
# 第18天，易感受：1279人， 已確診：0人， 已康復：1人
# 第19天，易感受：1279人， 已確診：0人， 已康復：1人
# 第20天，易感受：1279人， 已確診：0人， 已康復：1人
# 第0天，易感受：1050人， 已確診：1人， 已康復：0人
# 第1天，易感受：1050人， 已確診：0人， 已康復：1人
# 第2天，易感受：1050人， 已確診：0人， 已康復：1人
# 第3天，易感受：1050人， 已確診：0人， 已康復：1人
# 第4天，易感受：1050人， 已確診：0人， 已康復：1人
# 第5天，易感受：1050人， 已確診：0人， 已康復：1人
# 第6天，易感受：1050人， 已確診：0人， 已康復：1人
# 第7天，易感受：1050人， 已確診：0人， 已康復：1人
# 第8天，易感受：1050人， 已確診：0人， 已康復：1人
# 第9天，易感受：1050人， 已確診：0人， 已康復：1人
# 第10天，易感受：1050人， 已確診：0人， 已康復：1人
# 第11天，易感受：1050人， 已確診：0人， 已康復：1人
# 第12天，易感受：1050人， 已確診：0人， 已康復：1人
# 第13天，易感受：1050人， 已確診：0人， 已康復：1人
# 第14天，易感受：1050人， 已確診：0人， 已康復：1人
# 第15天，易感受：1050人， 已確診：0人， 已康復：1人
# 第16天，易感受：1050人， 已確診：0人， 已康復：1人
# 第17天，易感受：1050人， 已確診：0人， 已康復：1人
# 第18天，易感受：1050人， 已確診：0人， 已康復：1人
# 第19天，易感受：1050人， 已確診：0人， 已康復：1人
# 第20天，易感受：1050人， 已確診：0人， 已康復：1人
# 第0天，易感受：676人， 已確診：1人， 已康復：0人
# 第1天，易感受：675人， 已確診：1人， 已康復：1人
# 第2天，易感受：673人， 已確診：3人， 已康復：1人
# 第3天，易感受：672人， 已確診：4人， 已康復：1人
# 第4天，易感受：672人， 已確診：3人， 已康復：2人
# 第5天，易感受：671人， 已確診：3人， 已康復：3人
# 第6天，易感受：671人， 已確診：3人， 已康復：3人
# 第7天，易感受：671人， 已確診：1人， 已康復：5人
# 第8天，易感受：671人， 已確診：0人， 已康復：6人
# 第9天，易感受：671人， 已確診：0人， 已康復：6人
# 第10天，易感受：671人， 已確診：0人， 已康復：6人
# 第11天，易感受：671人， 已確診：0人， 已康復：6人
# 第12天，易感受：671人， 已確診：0人， 已康復：6人
# 第13天，易感受：671人， 已確診：0人， 已康復：6人
# 第14天，易感受：671人， 已確診：0人， 已康復：6人
# 第15天，易感受：671人， 已確診：0人， 已康復：6人
# 第16天，易感受：671人， 已確診：0人， 已康復：6人
# 第17天，易感受：671人， 已確診：0人， 已康復：6人
# 第18天，易感受：671人， 已確診：0人， 已康復：6人
# 第19天，易感受：671人， 已確診：0人， 已康復：6人
# 第20天，易感受：671人， 已確診：0人， 已康復：6人
# 第0天，易感受：1037人， 已確診：1人， 已康復：0人
# 第1天，易感受：1037人， 已確診：1人， 已康復：0人
# 第2天，易感受：1037人， 已確診：0人， 已康復：1人
# 第3天，易感受：1037人， 已確診：0人， 已康復：1人
# 第4天，易感受：1037人， 已確診：0人， 已康復：1人
# 第5天，易感受：1037人， 已確診：0人， 已康復：1人
# 第6天，易感受：1037人， 已確診：0人， 已康復：1人
# 第7天，易感受：1037人， 已確診：0人， 已康復：1人
# 第8天，易感受：1037人， 已確診：0人， 已康復：1人
# 第9天，易感受：1037人， 已確診：0人， 已康復：1人
# 第10天，易感受：1037人， 已確診：0人， 已康復：1人
# 第11天，易感受：1037人， 已確診：0人， 已康復：1人
# 第12天，易感受：1037人， 已確診：0人， 已康復：1人
# 第13天，易感受：1037人， 已確診：0人， 已康復：1人
# 第14天，易感受：1037人， 已確診：0人， 已康復：1人
# 第15天，易感受：1037人， 已確診：0人， 已康復：1人
# 第16天，易感受：1037人， 已確診：0人， 已康復：1人
# 第17天，易感受：1037人， 已確診：0人， 已康復：1人
# 第18天，易感受：1037人， 已確診：0人， 已康復：1人
# 第19天，易感受：1037人， 已確診：0人， 已康復：1人
# 第20天，易感受：1037人， 已確診：0人， 已康復：1人
